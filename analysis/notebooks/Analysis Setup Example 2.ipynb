# %% [markdown]
# # Analysis Setup Notebook
#
# This notebook demonstrates how to connect the `SSPIDatabaseConnector` to the local and remote application servers to making piping data into an analysis notebook quick and easy. Analysis can then be carried out in the familiar environment of notebooks then ported back to the application when it is ready.

# %% [markdown]
# ## Importing the Connector
# In the cell below, the first two lines modify your `PATH` environment variable so that it includes the location of the root of `sspi-data-webapp` repository (`../..` means *two directories up*). Then, we import the class. The main advantage of using this little connector class over just hitting the API directly with an HTTP request sent from `requests` is that it handles authentication using API Keys automatically.
#
# **Note: this quick and dirty modification only works inside of the `sspi-data-webapp/analysis/notebooks` directory. If you are doing analysis somewhere else for some reason and need to import `SSPIDatabaseConnector`, then you'll need to add a different directory to your path.**

# %%
import sys
sys.path.append("../..") # adjust the relative path if necessary
from connector.SSPIDatabaseConnector import SSPIDatabaseConnector

# %% [markdown]
# ## Call Local
# Remember that your application must be running in order to handle requests sent to the local application. Make sure you have flask running on port 5000! To run: open a terminal, `cd` into `sspi-data-webapp` repository, start the virtual environment, and run `flask run --debug`. You do *not* need an internet connection to do this, however!

# %%
sspi = SSPIDatabaseConnector()
res = sspi.call("/api/v1/query/sspi_indicator_data?SeriesCode=ALTNRG") # call to local (your app running on port 5000)
res.json()
# Out:
# []

# %% [markdown]
# ## Call Remote
#
# You need an internet connection to access the data at https://sspi.world. Additionally, you have less control over the state of the production database online than you do over the local database. If you're using finalized indicator data, getting it from online is probably fine, but if you're sourcing your own data for the analysis, then using the local database is usually easier.

# %%
sspi = SSPIDatabaseConnector()
res = sspi.call("/api/v1/query/sspi_indicator_data?SeriesCode=ALTNRG", remote=True) # call to remote (sspi.world)
res.json()
# Out:
# [{'CountryCode': 'BEL',
#   'Datasets': [{'CountryCode': 'BEL',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 442494.0,
#     'Year': 1990},
#    {'CountryCode': 'BEL',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 342021.0,
#     'Year': 1990},
#    {'CountryCode': 'BEL',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 466058.0,
#     'Year': 1990},
#    {'CountryCode': 'BEL',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 957.0,
#     'Year': 1990},
#    {'CountryCode': 'BEL',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 149.0,
#     'Year': 1990},
#    {'CountryCode': 'BEL',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 31596.0,
#     'Year': 1990},
#    {'CountryCode': 'BEL',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 735051.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'BEL',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 23.92884003872516,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.39881400064541933,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'BRA',
#   'Datasets': [{'CountryCode': 'BRA',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 404905.0,
#     'Year': 1990},
#    {'CountryCode': 'BRA',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 143458.0,
#     'Year': 1990},
#    {'CountryCode': 'BRA',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 24403.0,
#     'Year': 1990},
#    {'CountryCode': 'BRA',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 744148.0,
#     'Year': 1990},
#    {'CountryCode': 'BRA',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 671.0,
#     'Year': 1990},
#    {'CountryCode': 'BRA',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 2004270.0,
#     'Year': 1990},
#    {'CountryCode': 'BRA',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 2466743.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'BRA',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 30.600794872955422,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.5100132478825904,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'CAN',
#   'Datasets': [{'CountryCode': 'CAN',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 1015732.0,
#     'Year': 1990},
#    {'CountryCode': 'CAN',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 2291985.0,
#     'Year': 1990},
#    {'CountryCode': 'CAN',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 812032.0,
#     'Year': 1990},
#    {'CountryCode': 'CAN',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 1068253.0,
#     'Year': 1990},
#    {'CountryCode': 'CAN',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 93.0,
#     'Year': 1990},
#    {'CountryCode': 'CAN',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 469083.0,
#     'Year': 1990},
#    {'CountryCode': 'CAN',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 3203476.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'CAN',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 23.86866138774858,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.397811023129143,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'FIN',
#   'Datasets': [{'CountryCode': 'FIN',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 222641.0,
#     'Year': 1990},
#    {'CountryCode': 'FIN',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 91391.0,
#     'Year': 1990},
#    {'CountryCode': 'FIN',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 209629.0,
#     'Year': 1990},
#    {'CountryCode': 'FIN',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 39092.0,
#     'Year': 1990},
#    {'CountryCode': 'FIN',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 16.0,
#     'Year': 1990},
#    {'CountryCode': 'FIN',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 191068.0,
#     'Year': 1990},
#    {'CountryCode': 'FIN',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 396098.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'FIN',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 29.93830086048342,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.498971681008057,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'FRA',
#   'Datasets': [{'CountryCode': 'FRA',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 839423.0,
#     'Year': 1990},
#    {'CountryCode': 'FRA',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 1089912.0,
#     'Year': 1990},
#    {'CountryCode': 'FRA',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 3426338.0,
#     'Year': 1990},
#    {'CountryCode': 'FRA',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 189772.0,
#     'Year': 1990},
#    {'CountryCode': 'FRA',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 7449.0,
#     'Year': 1990},
#    {'CountryCode': 'FRA',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 460032.0,
#     'Year': 1990},
#    {'CountryCode': 'FRA',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 3518167.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'FRA',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 40.43161681456681,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.6738602802427801,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'DEU',
#   'Datasets': [{'CountryCode': 'DEU',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 5383859.0,
#     'Year': 1990},
#    {'CountryCode': 'DEU',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 2301912.0,
#     'Year': 1990},
#    {'CountryCode': 'DEU',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 1667566.0,
#     'Year': 1990},
#    {'CountryCode': 'DEU',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 62733.0,
#     'Year': 1990},
#    {'CountryCode': 'DEU',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 727.0,
#     'Year': 1990},
#    {'CountryCode': 'DEU',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 200850.0,
#     'Year': 1990},
#    {'CountryCode': 'DEU',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 5084557.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'DEU',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 12.456982640153816,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.20761637733589694,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'HUN',
#   'Datasets': [{'CountryCode': 'HUN',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 260759.0,
#     'Year': 1990},
#    {'CountryCode': 'HUN',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 373172.0,
#     'Year': 1990},
#    {'CountryCode': 'HUN',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 149792.0,
#     'Year': 1990},
#    {'CountryCode': 'HUN',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 640.0,
#     'Year': 1990},
#    {'CountryCode': 'HUN',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 3599.0,
#     'Year': 1990},
#    {'CountryCode': 'HUN',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 27486.0,
#     'Year': 1990},
#    {'CountryCode': 'HUN',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 349562.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'HUN',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 14.401078102333887,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.24001796837223147,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'IND',
#   'Datasets': [{'CountryCode': 'IND',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 3881055.0,
#     'Year': 1990},
#    {'CountryCode': 'IND',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 442571.0,
#     'Year': 1990},
#    {'CountryCode': 'IND',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 66992.0,
#     'Year': 1990},
#    {'CountryCode': 'IND',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 257961.0,
#     'Year': 1990},
#    {'CountryCode': 'IND',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 436.0,
#     'Year': 1990},
#    {'CountryCode': 'IND',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 4506866.0,
#     'Year': 1990},
#    {'CountryCode': 'IND',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 2558074.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'IND',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 22.01495566612643,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.3669159277687738,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'JPN',
#   'Datasets': [{'CountryCode': 'JPN',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 3211323.0,
#     'Year': 1990},
#    {'CountryCode': 'JPN',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 1847240.0,
#     'Year': 1990},
#    {'CountryCode': 'JPN',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 2206600.0,
#     'Year': 1990},
#    {'CountryCode': 'JPN',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 316446.0,
#     'Year': 1990},
#    {'CountryCode': 'JPN',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 117056.0,
#     'Year': 1990},
#    {'CountryCode': 'JPN',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 176757.0,
#     'Year': 1990},
#    {'CountryCode': 'JPN',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 10417270.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'JPN',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 14.915686001819742,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.2485947666969957,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'KOR',
#   'Datasets': [{'CountryCode': 'KOR',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 923094.0,
#     'Year': 1990},
#    {'CountryCode': 'KOR',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 111459.0,
#     'Year': 1990},
#    {'CountryCode': 'KOR',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 576949.0,
#     'Year': 1990},
#    {'CountryCode': 'KOR',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 22899.0,
#     'Year': 1990},
#    {'CountryCode': 'KOR',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 419.0,
#     'Year': 1990},
#    {'CountryCode': 'KOR',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 30591.0,
#     'Year': 1990},
#    {'CountryCode': 'KOR',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 2082274.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'KOR',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 16.42513978629474,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.273752329771579,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'MEX',
#   'Datasets': [{'CountryCode': 'MEX',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 172807.0,
#     'Year': 1990},
#    {'CountryCode': 'MEX',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 968259.0,
#     'Year': 1990},
#    {'CountryCode': 'MEX',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 32040.0,
#     'Year': 1990},
#    {'CountryCode': 'MEX',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 84520.0,
#     'Year': 1990},
#    {'CountryCode': 'MEX',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 185198.0,
#     'Year': 1990},
#    {'CountryCode': 'MEX',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 358132.0,
#     'Year': 1990},
#    {'CountryCode': 'MEX',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 3414463.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'MEX',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 9.219278451069798,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.1536546408511633,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'NLD',
#   'Datasets': [{'CountryCode': 'NLD',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 366895.0,
#     'Year': 1990},
#    {'CountryCode': 'NLD',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 1286500.0,
#     'Year': 1990},
#    {'CountryCode': 'NLD',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 38203.0,
#     'Year': 1990},
#    {'CountryCode': 'NLD',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 306.0,
#     'Year': 1990},
#    {'CountryCode': 'NLD',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 928.0,
#     'Year': 1990},
#    {'CountryCode': 'NLD',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 40383.0,
#     'Year': 1990},
#    {'CountryCode': 'NLD',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 1043512.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'NLD',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 2.147438332972597,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.03579063888287661,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'RUS',
#   'Datasets': [{'CountryCode': 'RUS',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 8001553.0,
#     'Year': 1990},
#    {'CountryCode': 'RUS',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 15381941.0,
#     'Year': 1990},
#    {'CountryCode': 'RUS',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 1310211.0,
#     'Year': 1990},
#    {'CountryCode': 'RUS',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 597301.0,
#     'Year': 1990},
#    {'CountryCode': 'RUS',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 1008.0,
#     'Year': 1990},
#    {'CountryCode': 'RUS',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 510043.0,
#     'Year': 1990},
#    {'CountryCode': 'RUS',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 11043845.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'RUS',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 5.871864664895434,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.09786441108159057,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'ESP',
#   'Datasets': [{'CountryCode': 'ESP',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 806670.0,
#     'Year': 1990},
#    {'CountryCode': 'ESP',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 208099.0,
#     'Year': 1990},
#    {'CountryCode': 'ESP',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 592014.0,
#     'Year': 1990},
#    {'CountryCode': 'ESP',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 91692.0,
#     'Year': 1990},
#    {'CountryCode': 'ESP',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 1060.0,
#     'Year': 1990},
#    {'CountryCode': 'ESP',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 170295.0,
#     'Year': 1990},
#    {'CountryCode': 'ESP',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 1903706.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'ESP',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 20.402972172519355,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.3400495362086559,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'SWE',
#   'Datasets': [{'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 123767.0,
#     'Year': 1990},
#    {'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 24155.0,
#     'Year': 1990},
#    {'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 743836.0,
#     'Year': 1990},
#    {'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 261010.0,
#     'Year': 1990},
#    {'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 154.0,
#     'Year': 1990},
#    {'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 230579.0,
#     'Year': 1990},
#    {'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 598825.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 56.51388823029109,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.9418981371715182,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'CHE',
#   'Datasets': [{'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 15044.0,
#     'Year': 1990},
#    {'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 68309.0,
#     'Year': 1990},
#    {'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 258737.0,
#     'Year': 1990},
#    {'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 107220.0,
#     'Year': 1990},
#    {'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 109.0,
#     'Year': 1990},
#    {'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 62100.0,
#     'Year': 1990},
#    {'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 513102.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 38.75735515863914,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.6459559193106524,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'TWN',
#   'Datasets': [{'CountryCode': 'TWN',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 479517.0,
#     'Year': 1990},
#    {'CountryCode': 'TWN',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 65795.0,
#     'Year': 1990},
#    {'CountryCode': 'TWN',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 358538.0,
#     'Year': 1990},
#    {'CountryCode': 'TWN',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 22248.0,
#     'Year': 1990},
#    {'CountryCode': 'TWN',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 929.0,
#     'Year': 1990},
#    {'CountryCode': 'TWN',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 2092.0,
#     'Year': 1990},
#    {'CountryCode': 'TWN',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 1187807.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'TWN',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 18.080981574226023,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.30134969290376706,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'GBR',
#   'Datasets': [{'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 2642424.0,
#     'Year': 1990},
#    {'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 1976311.0,
#     'Year': 1990},
#    {'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 717261.0,
#     'Year': 1990},
#    {'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 18745.0,
#     'Year': 1990},
#    {'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 493.0,
#     'Year': 1990},
#    {'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 26263.0,
#     'Year': 1990},
#    {'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 3197668.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 8.737802571695497,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.14563004286159162,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'USA',
#   'Datasets': [{'CountryCode': 'USA',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 19241158.0,
#     'Year': 1990},
#    {'CountryCode': 'USA',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 18353151.0,
#     'Year': 1990},
#    {'CountryCode': 'USA',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 6671880.0,
#     'Year': 1990},
#    {'CountryCode': 'USA',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 983347.0,
#     'Year': 1990},
#    {'CountryCode': 'USA',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 603936.0,
#     'Year': 1990},
#    {'CountryCode': 'USA',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 2606995.0,
#     'Year': 1990},
#    {'CountryCode': 'USA',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 31687493.0,
#     'Year': 1990},
#    {'Computed': True,
#     'CountryCode': 'USA',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 11.931258761919828,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1990}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.1988543126986638,
#   'Unit': 'Index',
#   'Year': 1990},
#  {'CountryCode': 'USA',
#   'Datasets': [{'CountryCode': 'USA',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 19026289.0,
#     'Year': 1991},
#    {'CountryCode': 'USA',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 19200736.0,
#     'Year': 1991},
#    {'CountryCode': 'USA',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 7084352.0,
#     'Year': 1991},
#    {'CountryCode': 'USA',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 1037538.0,
#     'Year': 1991},
#    {'CountryCode': 'USA',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 614066.0,
#     'Year': 1991},
#    {'CountryCode': 'USA',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 2746122.0,
#     'Year': 1991},
#    {'CountryCode': 'USA',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 31024594.0,
#     'Year': 1991},
#    {'Computed': True,
#     'CountryCode': 'USA',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 12.52143451327393,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1991}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.20869057522123216,
#   'Unit': 'Index',
#   'Year': 1991},
#  {'CountryCode': 'GBR',
#   'Datasets': [{'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 2657862.0,
#     'Year': 1991},
#    {'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 2130230.0,
#     'Year': 1991},
#    {'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 769559.0,
#     'Year': 1991},
#    {'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 16646.0,
#     'Year': 1991},
#    {'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 500.0,
#     'Year': 1991},
#    {'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 27814.0,
#     'Year': 1991},
#    {'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 3253082.0,
#     'Year': 1991},
#    {'Computed': True,
#     'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 9.040647637627004,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1991}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.15067746062711673,
#   'Unit': 'Index',
#   'Year': 1991},
#  {'CountryCode': 'TWN',
#   'Datasets': [{'CountryCode': 'TWN',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 526330.0,
#     'Year': 1991},
#    {'CountryCode': 'TWN',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 114500.0,
#     'Year': 1991},
#    {'CountryCode': 'TWN',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 384981.0,
#     'Year': 1991},
#    {'CountryCode': 'TWN',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 13208.0,
#     'Year': 1991},
#    {'CountryCode': 'TWN',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 1113.0,
#     'Year': 1991},
#    {'CountryCode': 'TWN',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 2841.0,
#     'Year': 1991},
#    {'CountryCode': 'TWN',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 1249956.0,
#     'Year': 1991},
#    {'Computed': True,
#     'CountryCode': 'TWN',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 17.476446065272846,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1991}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.29127410108788077,
#   'Unit': 'Index',
#   'Year': 1991},
#  {'CountryCode': 'CHE',
#   'Datasets': [{'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 12672.0,
#     'Year': 1991},
#    {'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 76689.0,
#     'Year': 1991},
#    {'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 251306.0,
#     'Year': 1991},
#    {'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 115333.0,
#     'Year': 1991},
#    {'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 143.0,
#     'Year': 1991},
#    {'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 67712.0,
#     'Year': 1991},
#    {'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 517895.0,
#     'Year': 1991},
#    {'Computed': True,
#     'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 38.458171346292296,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 1991}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.6409695224382049,
#   'Unit': 'Index',
#   'Year': 1991},
#  {'CountryCode': 'SWE',
#   'Datasets': [{'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 117772.0,
#     'Year': 1991},
#    {'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 25807.0,
#     'Year': 1991},
#    {'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 837392.0,
#     'Year': 1991},
#    {'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 227649.0,
#     'Year': 1991},
#    {'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 194.0,
#     'Year': 1991},
#    {'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 241306.0,
#     'Year': 1991},
#    {'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 593070.0,
#     'Year': 1991},
#    {'Computed': True,
#     'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 58.04100450765715,
# ...
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 173320.0,
#     'Year': 2024},
#    {'CountryCode': 'NLD',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 941322.0,
#     'Year': 2024},
#    {'CountryCode': 'NLD',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 38984.0,
#     'Year': 2024},
#    {'CountryCode': 'NLD',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 307.0,
#     'Year': 2024},
#    {'CountryCode': 'NLD',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 208017.0,
#     'Year': 2024},
#    {'CountryCode': 'NLD',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 202187.0,
#     'Year': 2024},
#    {'CountryCode': 'NLD',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 1011954.0,
#     'Year': 2024},
#    {'Computed': True,
#     'CountryCode': 'NLD',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 13.524425185290426,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 2024}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.22540708642150709,
#   'Unit': 'Index',
#   'Year': 2024},
#  {'CountryCode': 'SVK',
#   'Datasets': [{'CountryCode': 'SVK',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 79101.0,
#     'Year': 2024},
#    {'CountryCode': 'SVK',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 156451.0,
#     'Year': 2024},
#    {'CountryCode': 'SVK',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 200290.0,
#     'Year': 2024},
#    {'CountryCode': 'SVK',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 17254.0,
#     'Year': 2024},
#    {'CountryCode': 'SVK',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 3276.0,
#     'Year': 2024},
#    {'CountryCode': 'SVK',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 74086.0,
#     'Year': 2024},
#    {'CountryCode': 'SVK',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 163555.0,
#     'Year': 2024},
#    {'Computed': True,
#     'CountryCode': 'SVK',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 37.15535587950082,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 2024}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.6192559313250137,
#   'Unit': 'Index',
#   'Year': 2024},
#  {'CountryCode': 'SVN',
#   'Datasets': [{'CountryCode': 'SVN',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 32672.0,
#     'Year': 2024},
#    {'CountryCode': 'SVN',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 30811.0,
#     'Year': 2024},
#    {'CountryCode': 'SVN',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 63662.0,
#     'Year': 2024},
#    {'CountryCode': 'SVN',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 18884.0,
#     'Year': 2024},
#    {'CountryCode': 'SVN',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 7254.0,
#     'Year': 2024},
#    {'CountryCode': 'SVN',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 28876.0,
#     'Year': 2024},
#    {'CountryCode': 'SVN',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 95960.0,
#     'Year': 2024},
#    {'Computed': True,
#     'CountryCode': 'SVN',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 37.479640010211455,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 2024}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.6246606668368576,
#   'Unit': 'Index',
#   'Year': 2024},
#  {'CountryCode': 'ESP',
#   'Datasets': [{'CountryCode': 'ESP',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 102179.0,
#     'Year': 2024},
#    {'CountryCode': 'ESP',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 1007557.0,
#     'Year': 2024},
#    {'CountryCode': 'ESP',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 594898.0,
#     'Year': 2024},
#    {'CountryCode': 'ESP',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 123864.0,
#     'Year': 2024},
#    {'CountryCode': 'ESP',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 481571.0,
#     'Year': 2024},
#    {'CountryCode': 'ESP',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 346366.0,
#     'Year': 2024},
#    {'CountryCode': 'ESP',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 2091732.0,
#     'Year': 2024},
#    {'Computed': True,
#     'CountryCode': 'ESP',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 28.927289204444577,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 2024}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.48212148674074295,
#   'Unit': 'Index',
#   'Year': 2024},
#  {'CountryCode': 'SWE',
#   'Datasets': [{'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 66288.0,
#     'Year': 2024},
#    {'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 31832.0,
#     'Year': 2024},
#    {'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 549949.0,
#     'Year': 2024},
#    {'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 233373.0,
#     'Year': 2024},
#    {'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 195992.0,
#     'Year': 2024},
#    {'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 532845.0,
#     'Year': 2024},
#    {'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 405667.0,
#     'Year': 2024},
#    {'Computed': True,
#     'CountryCode': 'SWE',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 61.794140319234735,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 2024}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 1,
#   'Unit': 'Index',
#   'Year': 2024},
#  {'CountryCode': 'CHE',
#   'Datasets': [{'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 2601.0,
#     'Year': 2024},
#    {'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 100299.0,
#     'Year': 2024},
#    {'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 263376.0,
#     'Year': 2024},
#    {'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 163493.0,
#     'Year': 2024},
#    {'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 24498.0,
#     'Year': 2024},
#    {'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 131635.0,
#     'Year': 2024},
#    {'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 305346.0,
#     'Year': 2024},
#    {'Computed': True,
#     'CountryCode': 'CHE',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 52.17508635578584,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 2024}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.8695847725964306,
#   'Unit': 'Index',
#   'Year': 2024},
#  {'CountryCode': 'GBR',
#   'Datasets': [{'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 97205.0,
#     'Year': 2024},
#    {'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 2207144.0,
#     'Year': 2024},
#    {'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 442776.0,
#     'Year': 2024},
#    {'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 20751.0,
#     'Year': 2024},
#    {'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 363848.0,
#     'Year': 2024},
#    {'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 603875.0,
#     'Year': 2024},
#    {'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 2146689.0,
#     'Year': 2024},
#    {'Computed': True,
#     'CountryCode': 'GBR',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 19.198524451709947,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 2024}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.3199754075284991,
#   'Unit': 'Index',
#   'Year': 2024},
#  {'CountryCode': 'USA',
#   'Datasets': [{'CountryCode': 'USA',
#     'DatasetCode': 'IEA_TLCOAL',
#     'IndicatorCode': 'IEA_TLCOAL',
#     'IntermediateCode': 'TLCOAL',
#     'Unit': 'TJ',
#     'Value': 8005703.0,
#     'Year': 2024},
#    {'CountryCode': 'USA',
#     'DatasetCode': 'IEA_NATGAS',
#     'IndicatorCode': 'IEA_NATGAS',
#     'IntermediateCode': 'NATGAS',
#     'Unit': 'TJ',
#     'Value': 32561342.0,
#     'Year': 2024},
#    {'CountryCode': 'USA',
#     'DatasetCode': 'IEA_NCLEAR',
#     'IndicatorCode': 'IEA_NCLEAR',
#     'IntermediateCode': 'NCLEAR',
#     'Unit': 'TJ',
#     'Value': 8896952.0,
#     'Year': 2024},
#    {'CountryCode': 'USA',
#     'DatasetCode': 'IEA_HYDROP',
#     'IndicatorCode': 'IEA_HYDROP',
#     'IntermediateCode': 'HYDROP',
#     'Unit': 'TJ',
#     'Value': 878518.0,
#     'Year': 2024},
#    {'CountryCode': 'USA',
#     'DatasetCode': 'IEA_GEOPWR',
#     'IndicatorCode': 'IEA_GEOPWR',
#     'IntermediateCode': 'GEOPWR',
#     'Unit': 'TJ',
#     'Value': 3144774.0,
#     'Year': 2024},
#    {'CountryCode': 'USA',
#     'DatasetCode': 'IEA_BIOWAS',
#     'IndicatorCode': 'IEA_BIOWAS',
#     'IntermediateCode': 'BIOWAS',
#     'Unit': 'TJ',
#     'Value': 4458288.0,
#     'Year': 2024},
#    {'CountryCode': 'USA',
#     'DatasetCode': 'IEA_FSLOIL',
#     'IndicatorCode': 'IEA_FSLOIL',
#     'IntermediateCode': 'FSLOIL',
#     'Unit': 'TJ',
#     'Value': 32561614.0,
#     'Year': 2024},
#    {'Computed': True,
#     'CountryCode': 'USA',
#     'DatasetCode': 'IEA_ALTNRG_PERCENTAGE',
#     'Unit': '% of Total Energy Supply from Alternative Sources (Partial Credit for Biowaste)',
#     'Value': 16.738325245338793,
#     'ValueFunction': 'def altnrg_percent_value(IEA_TLCOAL, IEA_NATGAS, IEA_NCLEAR, IEA_HYDROP, IEA_GEOPWR, IEA_BIOWAS, IEA_FSLOIL):\n        return ((IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS) - 0.5 * IEA_BIOWAS) / (IEA_TLCOAL + IEA_NATGAS + IEA_NCLEAR + IEA_HYDROP + IEA_GEOPWR + IEA_BIOWAS + IEA_FSLOIL) * 100',
#     'Year': 2024}],
#   'IndicatorCode': 'ALTNRG',
#   'Score': 0.2789720874223132,
#   'Unit': 'Index',
#   'Year': 2024}]
