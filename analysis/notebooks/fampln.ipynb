# %%
# importing the connector
import sys
sys.path.append("../..") # adjust the relative path if necessary
from connector.SSPIDatabaseConnector import SSPIDatabaseConnector

# %%
# call local 
sspi = SSPIDatabaseConnector()
res = sspi.call("/api/v1/query/sspi_indicator_data?SeriesCode=BIODIV") # call to local (your app running on port 5000)
res.json()
# Out:
# No API key found in environment variables
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 # call local
# ----> 2 sspi = SSPIDatabaseConnector()
#       3 res = sspi.call("/api/v1/query/sspi_indicator_data?SeriesCode=BIODIV") # call to local (your app running on port 5000)
#       4 res.json()
#
# File ~/Desktop/SSPI/sspi-data-webapp/analysis/notebooks/../../connector/SSPIDatabaseConnector.py:16, in SSPIDatabaseConnector.__init__(self)
#      15 def __init__(self):
# ---> 16     self.remote_token = self.get_token()
#      17     self.local_token = self.get_token(token_name="SSPI_APIKEY_LOCAL")
#      18     ctx = ssl.create_default_context(ssl.Purpose.SERVER_AUTH)
#
# File ~/Desktop/SSPI/sspi-data-webapp/analysis/notebooks/../../connector/SSPIDatabaseConnector.py:46, in SSPIDatabaseConnector.get_token(self, token_name)
#      44 if key is None:
#      45     log.error("No API key found in environment variables")
# ---> 46     raise ValueError("No API key found in environment variables")
#      47 log.info("API key retrieval successful")
#      48 return key
#
# ValueError: No API key found in environment variables

# %%
print("done")
