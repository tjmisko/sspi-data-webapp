# %%
import pandas as pd
import requests

# %%
response = requests.get("127.0.0.1/api/v1/query/GTRANS?database=sspi_clean_api_data")
new_change = ""
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# /Users/tristanmisko/Documents/Projects/sspi-data-collection/analysis/oecd-iea-comparison.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/tristanmisko/Documents/Projects/sspi-data-collection/analysis/oecd-iea-comparison.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> response = requests.get("127.0.0.1/api/v1/query/GTRANS?sspi_clean_api_data")
#
# File ~/Documents/Projects/sspi-data-collection/env/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# ...
